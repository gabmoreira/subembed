# %% [markdown]
# # Flickr30k logical composition retrieval example

# %%
import torch
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
from datasets import load_dataset
from tqdm.auto import tqdm

from subspaces import join
from model import TransformerSubspaceEmbedder
from train_nli import NLITrainingData

CACHE_DIR = "./.cache"

device = "cuda:0" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ## Load SNLI-trained model

# %%
config = NLITrainingData.load("./nli_models/all-mpnet-base-v2_128x128_lbd0.05_context35_seed24_2way/config.pt")

model = TransformerSubspaceEmbedder(
    base_model_name=config.base_model_name,
    N=config.N,
    D=config.D,
    lbd=config.lbd,
    two_way=config.two_way,
    cache_dir=CACHE_DIR,
)
model.load_state_dict(config.state_dict, strict=True)
model.eval()
model.to(device)

text2projector = lambda text : model.encode([text], config.max_length, device=device)

# %% [markdown]
# ## Load Flickr30k

# %%
dataset = load_dataset("nlphuji/flickr30k", cache_dir=CACHE_DIR, split="test")
captions, img_indices = [], []

for i in range(len(dataset)):
    cs = dataset[i]["caption"]
    captions.extend(cs)
    img_indices.extend([i]*len(cs))

# %% [markdown]
# ## Compute Caption Subspaces (Soft Projectors)

# %%
B = 256
chunked_captions = [captions[i:i + B] for i in range(0, len(captions), B)]

P_captions = []
for chunk in tqdm(chunked_captions):
    with torch.no_grad():
        P = model.encode(chunk, max_length=config.max_length, device=device)
    P_captions.append(P)
P_captions = torch.cat(P_captions)

# %% [markdown]
# ## Retrieval with logical composition of queries

# %%
I = torch.eye(model.D, device=device)[None]
P_queries = {}

P1 = text2projector("people")
P2 = text2projector("sitting")
P3 = text2projector("on a bench")
P_queries["people AND sitting AND on a bench"] = P1 @ P2 @ P3

P1 = text2projector("food being prepared")
P2 = text2projector("outdoors on the grill")
P_queries["food being prepared AND outdoors on the grill"] = P1 @ P2

P1 = text2projector("an animal interacting with a human")
P2 = text2projector("in a zoo")
P_queries["an animal interacting with a human AND in a zoo"] = P1 @ P2

P1 = text2projector("a person walking")
P2 = text2projector("on the sidewalk")
P_queries["a person walking AND NOT on the sidewalk"] = P1 @ (I - P2)
P_queries["a person walking AND on the sidewalk"] = P1 @ P2

P1 = text2projector("a person riding a bicycle")
P2 = text2projector("a person walking a dog")
P_queries["a person riding a bicycle OR a person walking a dog"] = join(P1[0], P2[0], config.lbd)

P1 = text2projector("a group of people")
P2 = text2projector("military")
P_queries["a group of people AND military"] = P1 @ P2

P1 = text2projector("a man")
P2 = text2projector("on a boat")
P3 = text2projector("is fishing")
P_queries["a man AND NOT on a boat AND is fishing"] = P1 @ (I - P2) @ P3

P1 = text2projector("a person playing the violin")
P2 = text2projector("standing in the street")
P_queries["a person playing the violin AND NOT standing in the street"] = P1 @ (I - P2)
P_queries["a person playing the violin AND standing in the street"] = P1 @ P2

P1 = text2projector("a child playing outdoors")
P2 = text2projector("near a road")
P_queries["a child playing outdoors AND NOT near a road"] = P1 @ (I - P2)
P_queries["a child playing outdoors AND near a road"] = P1 @ P2

P1 = text2projector("a car")
P2 = text2projector("in the water")
P_queries["a cat in the water"] = P1 @ P2

P1 = text2projector("a car")
P2 = I - text2projector("is in an accident")
P_queries["a car in an accident"] = P1 @ P2 

P1 = text2projector("a dog")
P2 = I - text2projector("watching the sunset")
P_queries["a dog watching the sunset"] = P1 @ P2

# %%
P_query = P_queries["people AND sitting AND on a bench"]

P_captions = P_captions.to(device)
scores = torch.einsum("bii->b", P_query @ P_captions) / torch.einsum("bii->b", P_captions)
idx = torch.argsort(scores, descending=True)
for i in range(10):
    print(f"NIS: {scores[idx[i]].item():.3f} | Caption: {captions[idx[i]]} (idx {idx[i]})")

display_indices = []
i = 0
while len(display_indices) < 6:
    if img_indices[idx[i]] not in display_indices:
        display_indices.append(img_indices[idx[i]])
    i += 1

fig = plt.figure(figsize=(15, 2))
gs = gridspec.GridSpec(1, 6, wspace=0.05)

for i in range(6):
    ax = fig.add_subplot(gs[0, i])
    img = dataset[display_indices[i]]["image"]
    ax.imshow(img)
    ax.axis("off")
    ax.set_aspect('auto')
    print(dataset[display_indices[i]]["caption"])
#plt.savefig("./a_man_and_a_surfboard_AND_NOT_is_surfing.pdf", bbox_inches='tight', pad_inches=0)
